# %%
# %pip install --upgrade --quiet  langchain langchain-community langchainhub langchain-openai langchain-chroma bs4
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.5/973.5 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.2/310.2 kB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 19.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.8/526.8 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 35.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 53.1 MB/s eta 0:00:00
# ...

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !while true; do nohup ollama serve >/dev/null 2>&1; sleep 5; done >/dev/null 2>&1 &

# %%
# !ollama pull llama3
# Out:
# pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠏ pulling manifest ⠋ pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# pulling 6a0746a1ec1a...   0% ▕▏    0 B/4.7 GB                  pulling manifest
# ...

# %%
#check if llama is working
from langchain_community.llms import Ollama
llm = Ollama(model = "llama3")
llm.invoke("Tell me 3 red flower names.")
# Out:
# 'Here are three red flower names:\n\n1. Poppy\n2. Hollyhock\n3. Red Salvia'

# %%
# Loaders
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import PyPDFLoader

# %%
# !pip install pypdf rapidocr-onnxruntime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 43.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 52.6 MB/s eta 0:00:00
# ...

# %%
file_path="./66565e430ecefa65f5ccdf9b.pdf"
loader = PyPDFLoader(file_path, extract_images=True)
data = loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# Split and chunk
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
chunks = text_splitter.split_documents(data)

# %%
# !ollama pull nomic-embed-text
# Out:
# pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling 970aa74c0a90...   0% ▕▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   0% ▕▏    0 B/274 MB                  pulling manifest
# pulling 970aa74c0a90...   2% ▕▏ 6.5 MB/274 MB                  pulling manifest
# ...

# %%
#Add embedding to vector DB
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import Chroma

# %%
# Add to vector database
vector_db = Chroma.from_documents(
    documents=chunks,
    embedding=OllamaEmbeddings(model="nomic-embed-text",show_progress=True),
    collection_name="patient-rag"
)
# Out:
# OllamaEmbeddings: 100%|██████████| 21/21 [00:04<00:00,  4.80it/s]

# %%
# Retrieval
from langchain_community.chat_models import ChatOllama
from langchain.prompts import ChatPromptTemplate, PromptTemplate
from langchain.retrievers.multi_query import MultiQueryRetriever

# %%
# LLM from Ollama
local_model = "llama3"
llm = ChatOllama(model=local_model)


QUERY_PROMPT = PromptTemplate(
    input_variables=["question"],
    template="""You are an AI language model assistant. Your task is to generate five
    different versions of the given user question to retrieve relevant documents from
    a vector database. By generating multiple perspectives on the user question, your
    goal is to help the user overcome some of the limitations of the distance-based
    similarity search. Provide these alternative questions separated by newlines.
    Original question: {question}""",
)

retriever = MultiQueryRetriever.from_llm(
    vector_db.as_retriever(),
    llm,
    prompt=QUERY_PROMPT
)

# %%
# RAG prompt
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
template = """Answer the question based ONLY on the following context:
{context}
Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# %%
print(chain.invoke("can you suggest better plan for this patient treatment"))
# Out:
# ...
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00,  9.73it/s]
# Based on the provided context, I'll offer some suggestions to improve the treatment plan for Mendivil Araceli:
#
# 1. **Assess L scapula/GH joint**: As mentioned in the original plan, assessing the left scapula/GH joint is crucial for understanding the patient's pain patterns and developing an effective treatment approach.
# 2. **Incorporate exercises for scapular stabilization**: To address the clicking sensation in the left shoulder and scapula, incorporating exercises that promote scapular stabilization and strengthening would be beneficial (e.g., scapular push-ups, shoulder blade squeezes).
# 3. **Address cervical range of motion**: The patient's sensitivity to cervical flexion (looking up) and lifting may indicate limitations in their cervical range of motion. Incorporating gentle cervical stretches and exercises that promote increased ROM could help alleviate symptoms.
# ...

# %%
print(chain.invoke("can you suggest better plan for this patient treatment and please add hep info for exercise"))
# Out:
# ...
# OllamaEmbeddings: 100%|██████████| 1/1 [00:00<00:00, 10.18it/s]
# Based on the provided context, I'll suggest a comprehensive treatment plan for Mendivil Arac's neck and shoulder pain. Please note that this is not a personalized medical advice, but rather a general outline.
#
# **Short-term goals (0-4 weeks):**
#
# 1. **Reduce sensitivity and irritability**: Implement relaxation techniques like deep breathing exercises, progressive muscle relaxation, or guided imagery to manage symptoms.
# 2. **Improve posture and reduce pain**: Encourage Mendivil Arac to maintain good posture while standing, sitting, and sleeping. This can help alleviate pressure on her neck and shoulder muscles.
# 3. **Start gentle exercises**: Introduce low-impact exercises that target the affected areas, such as:
# 	* Cervical AROM (active range of motion) exercises: Gentle rotations, lateral flexions, and extensions to improve cervical mobility.
# ...

# %%
# !pip freeze > requirements.txt
